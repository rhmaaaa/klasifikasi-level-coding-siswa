# %%
import pandas as pd
df=pd.read_csv("level_coding_siswa_150.csv")
df
# Out:
#      hours_coding_daily preferred_language  typing_speed import_usage  \
# 0                   4.0             Python            44          Yes
# 1                   5.0                C++            59          Yes
# 2                   5.0             Python            55          Yes
# 3                   5.0             Python            59          Yes
# 4                   5.0             Python            55          Yes
# ..                  ...                ...           ...          ...
# 169                 2.5                C++            40           No
# 170                 4.0             Python            48          Yes
# 171                 5.0                C++            34          Yes
# 172                 3.5               Java            45          Yes
# 173                 3.0                C++            38          Yes
#
#     oop_usage         level
# 0         Yes      Advanced
# 1         Yes      Advanced
# 2         Yes      Advanced
# 3         Yes      Advanced
# 4         Yes      Advanced
# ..        ...           ...
# 169        No  Intermediate
# 170       Yes  Intermediate
# 171       Yes  Intermediate
# 172        No  Intermediate
# 173        No  Intermediate
#
# [174 rows x 6 columns]

# %%
df.columns
df
# Out:
#      hours_coding_daily preferred_language  typing_speed import_usage  \
# 0                   4.0             Python            44          Yes
# 1                   5.0                C++            59          Yes
# 2                   5.0             Python            55          Yes
# 3                   5.0             Python            59          Yes
# 4                   5.0             Python            55          Yes
# ..                  ...                ...           ...          ...
# 169                 2.5                C++            40           No
# 170                 4.0             Python            48          Yes
# 171                 5.0                C++            34          Yes
# 172                 3.5               Java            45          Yes
# 173                 3.0                C++            38          Yes
#
#     oop_usage         level
# 0         Yes      Advanced
# 1         Yes      Advanced
# 2         Yes      Advanced
# 3         Yes      Advanced
# 4         Yes      Advanced
# ..        ...           ...
# 169        No  Intermediate
# 170       Yes  Intermediate
# 171       Yes  Intermediate
# 172        No  Intermediate
# 173        No  Intermediate
#
# [174 rows x 6 columns]

# %%
df.shape
df
# Out:
#      hours_coding_daily preferred_language  typing_speed import_usage  \
# 0                   4.0             Python            44          Yes
# 1                   5.0                C++            59          Yes
# 2                   5.0             Python            55          Yes
# 3                   5.0             Python            59          Yes
# 4                   5.0             Python            55          Yes
# ..                  ...                ...           ...          ...
# 169                 2.5                C++            40           No
# 170                 4.0             Python            48          Yes
# 171                 5.0                C++            34          Yes
# 172                 3.5               Java            45          Yes
# 173                 3.0                C++            38          Yes
#
#     oop_usage         level
# 0         Yes      Advanced
# 1         Yes      Advanced
# 2         Yes      Advanced
# 3         Yes      Advanced
# 4         Yes      Advanced
# ..        ...           ...
# 169        No  Intermediate
# 170       Yes  Intermediate
# 171       Yes  Intermediate
# 172        No  Intermediate
# 173        No  Intermediate
#
# [174 rows x 6 columns]

# %%
df.describe
df
# Out:
#      hours_coding_daily preferred_language  typing_speed import_usage  \
# 0                   4.0             Python            44          Yes
# 1                   5.0                C++            59          Yes
# 2                   5.0             Python            55          Yes
# 3                   5.0             Python            59          Yes
# 4                   5.0             Python            55          Yes
# ..                  ...                ...           ...          ...
# 169                 2.5                C++            40           No
# 170                 4.0             Python            48          Yes
# 171                 5.0                C++            34          Yes
# 172                 3.5               Java            45          Yes
# 173                 3.0                C++            38          Yes
#
#     oop_usage         level
# 0         Yes      Advanced
# 1         Yes      Advanced
# 2         Yes      Advanced
# 3         Yes      Advanced
# 4         Yes      Advanced
# ..        ...           ...
# 169        No  Intermediate
# 170       Yes  Intermediate
# 171       Yes  Intermediate
# 172        No  Intermediate
# 173        No  Intermediate
#
# [174 rows x 6 columns]

# %%
df.head()
# Out:
#    hours_coding_daily preferred_language  typing_speed import_usage oop_usage  \
# 0                 4.0             Python            44          Yes       Yes
# 1                 5.0                C++            59          Yes       Yes
# 2                 5.0             Python            55          Yes       Yes
# 3                 5.0             Python            59          Yes       Yes
# 4                 5.0             Python            55          Yes       Yes
#
#       level
# 0  Advanced
# 1  Advanced
# 2  Advanced
# 3  Advanced
# 4  Advanced

# %%
df.tail()
# Out:
#      hours_coding_daily preferred_language  typing_speed import_usage  \
# 169                 2.5                C++            40           No
# 170                 4.0             Python            48          Yes
# 171                 5.0                C++            34          Yes
# 172                 3.5               Java            45          Yes
# 173                 3.0                C++            38          Yes
#
#     oop_usage         level
# 169        No  Intermediate
# 170       Yes  Intermediate
# 171       Yes  Intermediate
# 172        No  Intermediate
# 173        No  Intermediate

# %%
df.info
df
# Out:
#      hours_coding_daily preferred_language  typing_speed import_usage  \
# 0                   4.0             Python            44          Yes
# 1                   5.0                C++            59          Yes
# 2                   5.0             Python            55          Yes
# 3                   5.0             Python            59          Yes
# 4                   5.0             Python            55          Yes
# ..                  ...                ...           ...          ...
# 169                 2.5                C++            40           No
# 170                 4.0             Python            48          Yes
# 171                 5.0                C++            34          Yes
# 172                 3.5               Java            45          Yes
# 173                 3.0                C++            38          Yes
#
#     oop_usage         level
# 0         Yes      Advanced
# 1         Yes      Advanced
# 2         Yes      Advanced
# 3         Yes      Advanced
# 4         Yes      Advanced
# ..        ...           ...
# 169        No  Intermediate
# 170       Yes  Intermediate
# 171       Yes  Intermediate
# 172        No  Intermediate
# 173        No  Intermediate
#
# [174 rows x 6 columns]

# %%
df["preferred_language"].value_counts()
# Out:
# preferred_language
# Python    60
# C++       59
# Java      55
# Name: count, dtype: int64

# %%
df["import_usage"].value_counts()
# Out:
# import_usage
# Yes    92
# No     82
# Name: count, dtype: int64

# %%
df["oop_usage"].value_counts()
# Out:
# oop_usage
# No     93
# Yes    81
# Name: count, dtype: int64

# %%
df["level"].value_counts()
# Out:
# level
# Advanced        64
# Beginner        59
# Intermediate    51
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

Advanced = df[df["level"]=="Advanced"]
Beginner = df[df["level"]=="Beginner"]
Intermediate =df[df["level"]=="Intermediate"]

plt.scatter(Advancede["Hours_Coding_Daily"],Advance["Typing_Speed"] s=100, alpha 0.7, color="blue", Label="Avanced")
plt.scatter(Beginner["Hours_Coding_Daily"],Beginner["Typing_Speed"] s=100, alpha 0.7, color="orange", Label="Beginner")
plt.scatter(Intermediate["Hours_Coding_Daily"],Intermediate["Typing_Speed"] s=100, alpha 0.7, color="green", Label="Intermediater")
plt.xlabel=("Hours Coding Daily")
plt.ylabel=("Typing Speed")
plt.title=("Hours Coding Daily VS Typing Speed")
plt.legend()
plt.grid(True,linestyle"--"s=70 alpha 0.5)
plt.show()
# Out:
#   Cell In[31], line 7
#     plt.scatter(Advancede["Hours_Coding_Daily"],Advance["Typing_Speed"] s=100, alpha 0,7, color="blue", Label="Avanced")
#                                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
from sklearn.ensembel import RandomForestClassifier
from sklearn.model import classificassion
# Out:
#   Cell In[30], line 2
#     from sklearn
#                 ^
# SyntaxError: invalid syntax
